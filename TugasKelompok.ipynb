# %% [markdown]
# <a href="https://colab.research.google.com/github/AqsaHerryPrastyo/PCVK/blob/main/TugasKelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import cv2
import numpy as np
import matplotlib.pyplot as plt  # Perbaikan: harus pyplot bukan matplotlib saja
from google.colab.patches import cv2_imshow # untuk tampilkan gambar di Colab

# Baca gambar KTM dari Google Drive
img = cv2.imread('/content/drive/My Drive/Colab Notebooks/KTMHerry.jpeg')

# Cek apakah gambar berhasil dibaca
if img is None:
    print("Gambar nggak ketemu, cek lagi nama filenya di Drive!")
else:
    print("Gambar berhasil dibaca!")
    print(f"Ukuran gambar: {img.shape}")




    img_edited = img.copy()


    nama_x1, nama_y1 = 400, 840
    nama_x2, nama_y2 = 800, 800


    nim_x1, nim_y1 = 390, 910
    nim_x2, nim_y2 = 800, 850



    cv2.rectangle(img_edited, (nama_x1, nama_y1), (nama_x2, nama_y2), (255, 0, 0), -1)


    cv2.rectangle(img_edited, (nim_x1, nim_y1), (nim_x2, nim_y2), (0, 0, 255), -1)

    # Tampilkan gambar hasil edit dengan matplotlib
    print("\nGambar Setelah Diedit (dengan koordinat):")
    plt.figure(figsize=(12, 8))
    img_edited_rgb = cv2.cvtColor(img_edited, cv2.COLOR_BGR2RGB)
    plt.imshow(img_edited_rgb)
    plt.title('KTM Setelah Diedit')
    plt.axis('on')
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Gambar berhasil dibaca!
# Ukuran gambar: (1026, 1599, 3)
#
# Gambar Setelah Diedit (dengan koordinat):
